# %% [markdown]
# <a href="https://colab.research.google.com/github/thummavaishnavi/Machine-Learning/blob/main/ML_SplittingDatasetSolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Splitting of Dataset

# %% [markdown]
# <h2> Importing Libraries </h2>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2> Importing Dataset </h2>

# %%
df = pd.read_csv('/content/Dataset_4(Salary).csv')

# %%
df.head()
# Out:
#   country   Salary  YearsExperience Purchased
# 0   Dubai  39343.0              1.1        No
# 1  Canada  46205.0              1.3       Yes
# 2  Canada  37731.0              1.5        No
# 3  Canada  43525.0              2.0        No
# 4     USA  39891.0              2.2        No

# %% [markdown]
# <h2> Dividing into Target and Predictor Variables </h2>

# %%
# In X we store predictor variables.
# Here X will be dataframe because it has more than one features(columns).
X = df.iloc[:,:-1]
#In y we store target variables.
#Here y will be pandas series as it has only one feature(column).
y = df.iloc[:,-1]

#Here we are using X,y as dataframe because it has nice represenatation so you can understand it without confusion.
#But you can also use X,y as numpy array by this method.
        #X = df.iloc[:,:-1].values
        #y = df.iloc[:,-1].values

# %% [markdown]
# <h2> Divide Data as Training Set and Testing Set </h2>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 90)

# %%
X_train
# Out:
#       country    Salary  YearsExperience
# 29     Canada  121872.0             10.5
# 6      Canada   60150.0              3.0
# 20     Canada   91738.0              6.8
# 23  Australia  113812.0              8.2
# 25  Australia  105582.0              9.0
# 14  Australia   61111.0              4.5
# 8       Dubai   64445.0              3.2
# 22  Australia  101302.0              7.9
# 15        USA   67938.0              4.9
# 21  Australia   98273.0              7.1
# 9       Dubai   57189.0              3.7
# 13     Canada   57081.0              4.1
# 16        USA   66029.0              5.1
# 19     Canada   93940.0              6.0
# 11        USA   55794.0              4.0
# 0       Dubai   39343.0              1.1
# 10      Dubai   63218.0              3.9
# 28        USA  122391.0             10.3
# 5       Dubai   56642.0              2.9
# 4         USA   39891.0              2.2
# 7   Australia   54445.0              3.2
# 3      Canada   43525.0              2.0
# 18  Australia   81363.0              5.9
# 27        USA  112635.0              9.6

# %%
X_test
# Out:
#    country    Salary  YearsExperience
# 17  Canada   83088.0              5.3
# 24   Dubai  109431.0              8.7
# 26   Dubai  116969.0              9.5
# 2   Canada   37731.0              1.5
# 1   Canada   46205.0              1.3
# 12   Dubai   56957.0              4.0

# %%
y_train
# Out:
# 29    Yes
# 6     Yes
# 20     No
# 23    Yes
# 25    Yes
# 14     No
# 8     Yes
# 22     No
# 15     No
# 21     No
# 9      No
# 13     No
# 16     No
# 19     No
# 11     No
# 0      No
# 10    Yes
# 28     No
# 5      No
# 4      No
# 7      No
# 3      No
# 18    Yes
# 27    Yes
# Name: Purchased, dtype: object

# %%
y_test
# Out:
# 17     No
# 24     No
# 26     No
# 2      No
# 1     Yes
# 12    Yes
# Name: Purchased, dtype: object
